# %%
import pandas as pd
import numpy as np

# %%
names = ['Oswald', 'Richard', 'Victor', 'Walter', 'Ronald', 'Rebecca', 'Maurice', 'Margret']
scores = [7, 8, 4.7, 10, 9.5, 6, 5, 7.7]
result = ['yes', 'yes', 'no', 'yes', 'yes', 'no', 'no', 'yes']

# %%
df = pd.DataFrame({'name': names, 'score': scores, 'result': result})
df
# Out:
#       name  score result
# 0   Oswald    7.0    yes
# 1  Richard    8.0    yes
# 2   Victor    4.7     no
# 3   Walter   10.0    yes
# 4   Ronald    9.5    yes
# 5  Rebecca    6.0     no
# 6  Maurice    5.0     no
# 7  Margret    7.7    yes

# %%
df.describe()
# Out:
#           score
# count   8.00000
# mean    7.23750
# std     1.94858
# min     4.70000
# 25%     5.75000
# 50%     7.35000
# 75%     8.37500
# max    10.00000

# %%
df.min()
# Out:
# name      Margret
# score         4.7
# result         no
# dtype: object

# %%
df.max()
# Out:
# name      Walter
# score       10.0
# result       yes
# dtype: object

# %%
df[df['result'] == 'yes']
# Out:
#       name  score result
# 0   Oswald    7.0    yes
# 1  Richard    8.0    yes
# 3   Walter   10.0    yes
# 4   Ronald    9.5    yes
# 7  Margret    7.7    yes

# %%
df.to_csv('Task_1.csv', index=False)
