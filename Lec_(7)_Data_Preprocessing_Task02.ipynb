# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/content/employees_20.csv', index_col = "AR")

# %%
df
# Out:
#              Name  Age                      Email
# AR
# 1   Alice Johnson   33  alice.johnson@outlook.com
# 2       Bob Smith   47        bob.smith@yahoo.com
# 3   Charlie Brown   39    charlie.brown@yahoo.com
# 4    Diana Prince   46   diana.prince@outlook.com
# 5      Ethan Hunt   28       ethan.hunt@gmail.com
# 6     Fiona Adams   31    fiona.adams@outlook.com
# 7    George Baker   40   george.baker@outlook.com
# 8    Hannah Clark   38     hannah.clark@gmail.com
# 9       Ian Davis   42      ian.davis@outlook.com
# 10    Julia Evans   54      julia.evans@yahoo.com
# 11   Kevin Foster   22   kevin.foster@outlook.com
# 12    Laura Green   43      laura.green@yahoo.com
# 13   Michael Hill   27     michael.hill@yahoo.com
# 14     Nina Irwin   46       nina.irwin@yahoo.com
# 15    Oscar Jones   25    oscar.jones@outlook.com
# 16     Paula King   45       paula.king@yahoo.com
# 17    Quinn Lewis   41      quinn.lewis@gmail.com
# 18  Rachel Morris   33    rachel.morris@yahoo.com
# ...

# %%
df['Email_Provider'] = df['Email'].apply(lambda x: x.split('@')[1])
display(df)
# Out:
#              Name  Age                      Email Email_Provider
# AR
# 1   Alice Johnson   33  alice.johnson@outlook.com    outlook.com
# 2       Bob Smith   47        bob.smith@yahoo.com      yahoo.com
# 3   Charlie Brown   39    charlie.brown@yahoo.com      yahoo.com
# 4    Diana Prince   46   diana.prince@outlook.com    outlook.com
# 5      Ethan Hunt   28       ethan.hunt@gmail.com      gmail.com
# 6     Fiona Adams   31    fiona.adams@outlook.com    outlook.com
# 7    George Baker   40   george.baker@outlook.com    outlook.com
# 8    Hannah Clark   38     hannah.clark@gmail.com      gmail.com
# 9       Ian Davis   42      ian.davis@outlook.com    outlook.com
# 10    Julia Evans   54      julia.evans@yahoo.com      yahoo.com
# 11   Kevin Foster   22   kevin.foster@outlook.com    outlook.com
# 12    Laura Green   43      laura.green@yahoo.com      yahoo.com
# 13   Michael Hill   27     michael.hill@yahoo.com      yahoo.com
# ...

# %%
df['Email_Provider'].value_counts()
# Out:
# Email_Provider
# yahoo.com      9
# outlook.com    7
# gmail.com      4
# Name: count, dtype: int64

# %%
df.to_csv('Task_2.csv', index=False)
